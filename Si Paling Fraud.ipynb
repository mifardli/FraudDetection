# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#as usual, import the data
df_train = pd.read_csv("/Users/miftahulardli/Downloads/testFraud/fraudTrain.csv")

# %%
# Set the display option to show all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the DataFrame
df_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street            city state    zip  \
# 0    Banks      F                561 Perry Cove  Moravian Falls    NC  28654
# ...

# %%
df_train.tail()
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  \
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072
# ...

# %%
df_train.shape
# Out:
# (1296675, 23)

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
#delete some weird columns
df_train = df_train.drop('Unnamed: 0', axis='columns')

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  object
#  1   cc_num                 1296675 non-null  int64
#  2   merchant               1296675 non-null  object
#  3   category               1296675 non-null  object
#  4   amt                    1296675 non-null  float64
#  5   first                  1296675 non-null  object
#  6   last                   1296675 non-null  object
#  7   gender                 1296675 non-null  object
#  8   street                 1296675 non-null  object
#  9   city                   1296675 non-null  object
#  10  state                  1296675 non-null  object
#  11  zip                    1296675 non-null  int64
#  12  lat                    1296675 non-null  float64
#  13  long                   1296675 non-null  float64
# ...

# %%
df_train.describe()
# Out:
#              cc_num           amt           zip           lat          long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01 -9.022634e+01
# std    1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00  1.375908e+01
# min    6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01 -1.656723e+02
# 25%    1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01 -9.679800e+01
# 50%    3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01 -8.747690e+01
# 75%    4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01 -8.015800e+01
# max    4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01 -6.795030e+01
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01  5.788652e-03
# ...

# %%
df_train.nunique()
# Out:
# trans_date_trans_time    1274791
# cc_num                       983
# merchant                     693
# category                      14
# amt                        52928
# first                        352
# last                         481
# gender                         2
# street                       983
# city                         894
# state                         51
# zip                          970
# lat                          968
# long                         969
# city_pop                     879
# job                          494
# dob                          968
# trans_num                1296675
# unix_time                1274823
# merch_lat                1247805
# merch_long               1275745
# is_fraud                       2
# dtype: int64

# %%
#separate object and numerical columns
# Separating object (categorical) columns and numerical columns
object_columns = df_train.select_dtypes(include=['object']).columns
numeric_columns = df_train.select_dtypes(exclude=['object']).columns

print("Object (Categorical) Columns:")
print(object_columns)
print("\nNumeric Columns:")
print(numeric_columns)
# Out:
# Object (Categorical) Columns:
# Index(['trans_date_trans_time', 'merchant', 'category', 'first', 'last',
#        'gender', 'street', 'city', 'state', 'job', 'dob', 'trans_num'],
#       dtype='object')
#
# Numeric Columns:
# Index(['cc_num', 'amt', 'zip', 'lat', 'long', 'city_pop', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_train['category'].unique()
# Out:
# array(['misc_net', 'grocery_pos', 'entertainment', 'gas_transport',
#        'misc_pos', 'grocery_net', 'shopping_net', 'shopping_pos',
#        'food_dining', 'personal_care', 'health_fitness', 'travel',
#        'kids_pets', 'home'], dtype=object)

# %%
df_train['category'].value_counts()
# Out:
# category
# gas_transport     131659
# grocery_pos       123638
# home              123115
# shopping_pos      116672
# kids_pets         113035
# shopping_net       97543
# entertainment      94014
# food_dining        91461
# personal_care      90758
# health_fitness     85879
# misc_pos           79655
# misc_net           63287
# grocery_net        45452
# travel             40507
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set a Seaborn style (optional)
sns.set_style("whitegrid")

plt.figure(figsize=(12, 6))
plot = sns.countplot(x='category', data=df_train, palette='viridis')  # Adjust the palette for color variation

# Rotate x-axis labels for better readability
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, ha="right")

plt.title('Count of Categories', fontsize=16)  # Add a title
plt.xlabel('Category', fontsize=12)  # Label for x-axis
plt.ylabel('Count', fontsize=12)  # Label for y-axis

plt.tight_layout()  # Adjust layout to prevent label cutoff
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


category_counts = df_train['category'].value_counts()

# Set a Seaborn style (optional)
sns.set_style("whitegrid")

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel', len(category_counts)))

plt.title('Distribution of Categories', fontsize=16)  # Add a title
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualization

# %%
#install the module due to i have some modules that not yet to be installed
# !pip install plotly
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
import plotly.express as px

# Get counts of each category and create a DataFrame
category_counts = df_train['category'].value_counts().reset_index()
category_counts.columns = ['Category', 'Count']

# Use Plotly Express to create a bar chart
bar_chart_type = px.bar(category_counts, x='Category', y='Count', title='Frequency of Transaction Types')

# Show the chart external browser because bapuk
bar_chart_type.show(renderer="browser")  # Opens the chart in an external browser window

# %%
import plotly.graph_objects as go

# Calculate unique categories
category_labels = df_train['category'].value_counts().index.tolist()
category_values = df_train['category'].value_counts().values.tolist()

# Create the Pie 
pie_chart_type = go.Figure(data=[go.Pie(labels=category_labels, values=category_values)])

# Set layout options
pie_chart_type.update_traces(textposition='inside', textinfo='percent+label')

# title
pie_chart_type.update_layout(title='Proportion of Transaction Types')

# Show the chart in another browser tab due to my jupyter issues
pie_chart_type.show(renderer='browser')

# %%
#check the data fraud

# %%
df_train['is_fraud'].unique()
# Out:
# array([0, 1])

# %%
df_train['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust the figure size as you like

# Create the count plot 
ax = sns.countplot(x='is_fraud', data=df_train, palette='coolwarm')

# Set labels, title
plt.title('Count of Fraudulent Transactions', fontsize=16)
plt.xlabel('Is Fraudulent', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Customize the x-axis labels
ax.set_xticklabels(['Not Fraud', 'Fraud'], fontsize=11)  # Modify labels if 'is_fraud' is a binary categorical variable

# Add annotations (counts) 
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Get counts of 'is_fraud' columns
fraud_counts = df_train['is_fraud'].value_counts()

# Set up the figure 
plt.figure(figsize=(10, 8))  # Adjust the figure size for better presentation

# Define colors 
colors = ['#ff9999', '#66b3ff']

# Create the pie chart
plt.pie(fraud_counts, labels=fraud_counts.index, autopct='%1.1f%%', colors=colors, startangle=90, textprops={'fontsize': 12, 'color': 'black', 'weight': 'bold'})

# Title and visual 
plt.title('Distribution of Fraudulent Transactions', size=18, weight='bold', y=1.05)

plt.axis('equal')  # aspect ratio

plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# Calculate counts of 'is_fraud' values
fraud_counts = df_train['is_fraud'].value_counts().reset_index()
fraud_counts.columns = ['is_fraud', 'Count']

# Create the bar chart using Plotly Express
bar_chart_type = px.bar(fraud_counts, x='is_fraud', y='Count', color='is_fraud',
                        labels={'is_fraud': 'Is Fraudulent', 'Count': 'Count'},
                        title='Frequency of Fraudulent Transactions')

# Show the chart in another browser tab
bar_chart_type.show(renderer='browser')

# %%
import plotly.graph_objects as go

# Calculate the counts of 'is_fraud' values
fraud_counts = df_train['is_fraud'].value_counts()

# Create the Pie chart
pie_chart_fraud = go.Figure(data=[go.Pie(labels=fraud_counts.index, values=fraud_counts)])

# Update layout and title
pie_chart_fraud.update_layout(title='Proportion of Fraudulent Transactions')

# Show the chart in an external browser tab
pie_chart_fraud.show(renderer='browser')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter numerical columns excluding 'is_fraud'
numerical_columns = [col for col in df_train.columns if df_train[col].dtype != 'object' and col != 'is_fraud']

# Customize Seaborn style
sns.set(style="whitegrid", palette="hls")

# Plot histograms for each numerical column
for i in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df_train[i], kde=True, bins=20)
    plt.title(f'Histogram of {i}', fontsize=16)
    plt.xlabel('')
    plt.ylabel('Frequency', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter numerical columns excluding 'is_fraud'
numerical_columns = [col for col in df_train.columns if df_train[col].dtype != 'object' and col != 'is_fraud']

# Customize Seaborn style
sns.set(style="whitegrid", palette="hls")

# Plot boxplots for each numerical column
for i in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df_train[i])
    plt.title(f'Boxplot of {i}', fontsize=16)
    plt.xlabel('')
    plt.ylabel('Value', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter numerical columns excluding 'is_fraud'
numerical_columns = [col for col in df_train.columns if df_train[col].dtype != 'object' and col != 'is_fraud']

# Customize Seaborn style
sns.set(style="whitegrid", palette="hls")

# Plot violin plots 
for i in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.violinplot(x=df_train[i], palette="hls")
    plt.title(f'Violin Plot of {i}', fontsize=16)
    plt.xlabel('')
    plt.ylabel('Value', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))  # Adjust the figure size

# Customize Seaborn style
sns.set(style="whitegrid", palette='hls')

# Create the box plot
ax = sns.boxplot(x='category', y='amt', data=df_train, palette='Pastel1')

# Rotate x-axis labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set title and labels
plt.title('Box Plot of Amount by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Amount', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))  # Adjust the figure size

# Customize Seaborn style
sns.set(style="whitegrid", palette="pastel")

# Create the violin plot
ax = sns.violinplot(x='category', y='amt', data=df_train)

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set title and labels
plt.title('Violin Plot of Amount by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Amount', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))  # Adjust the figure size

# Customize Seaborn style
sns.set(style="whitegrid", palette="coolwarm")

# Create the bar plot
ax = sns.barplot(x='amt', y='category', data=df_train, ci=None)

# Rotate y-axis labels for better readability
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)

# Set title and labels
plt.title('Bar Plot of Amount by Category', fontsize=16)
plt.xlabel('Amount', fontsize=12)
plt.ylabel('Category', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))  # Adjust the figure

# Customize Seaborn 
sns.set(style="whitegrid", palette="pastel")

# Create the bar plot
ax = sns.barplot(x='category', y='is_fraud', data=df_train, ci=None)

# Rotate x-axis labels for readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set title and labels
plt.title('Bar Plot of Fraud by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Fraudulent', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))  # Adjust the figure size

# Customize Seaborn style
sns.set(style="whitegrid", palette="coolwarm")

# Create the bar plot
ax = sns.barplot(x='is_fraud', y='amt', data=df_train, ci=None)

# Rotate x-axis labels for readability
ax.set_xticklabels(['Not Fraud', 'Fraud'])

# Set title and labels
plt.title('Bar Plot of Amount by Fraudulent Status', fontsize=16)
plt.xlabel('Fraudulent Status', fontsize=12)
plt.ylabel('Amount', fontsize=12)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df_train['is_fraud'], y = df_train['category'], data = df_train, ci = None, palette = 'hls')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))  # Adjust the figure size

# Customize Seaborn style
sns.set(style="whitegrid", palette="husl")

# Create the bar plot
ax = sns.barplot(x='is_fraud', y='category', data=df_train, ci=None)


# Set title and labels
plt.title('Bar Plot of Category by Fraudulent Status', fontsize=16)
plt.xlabel('Fraudulent Status', fontsize=12)
plt.ylabel('Category', fontsize=12)

plt.tight_layout()
plt.show()

# %%
#Extract the datetime

# Convert 'trans_date_trans_time' to datetime format
df_train['trans_date_trans_time'] = pd.to_datetime(df_train['trans_date_trans_time'])

# Extract 'date', 'hours', and 'minutes' into separate columns
df_train['date'] = df_train['trans_date_trans_time'].dt.date
df_train['time'] = df_train['trans_date_trans_time'].dt.time

# Display the updated DataFrame with new columns
print(df_train[['trans_date_trans_time', 'date', 'time']].head())
# Out:
#   trans_date_trans_time        date      time
# 0   2019-01-01 00:00:18  2019-01-01  00:00:18
# 1   2019-01-01 00:00:44  2019-01-01  00:00:44
# 2   2019-01-01 00:00:51  2019-01-01  00:00:51
# 3   2019-01-01 00:01:16  2019-01-01  00:01:16
# 4   2019-01-01 00:03:06  2019-01-01  00:03:06

# %%
# Select numeric columns
numeric_df = df_train.select_dtypes(include='number')  # Selects all numeric columns

# Select non-numeric (object) columns
non_numeric_df = df_train.select_dtypes(exclude='number')  # Selects all non-numeric columns

# Display the two separate DataFrames
print("Numeric Columns:")
print(numeric_df.head())

print("\nNon-Numeric Columns:")
print(non_numeric_df.head())
# Out:
# Numeric Columns:
#              cc_num     amt    zip      lat      long  city_pop   unix_time  \
# 0  2703186189652095    4.97  28654  36.0788  -81.1781      3495  1325376018
# 1      630423337322  107.23  99160  48.8878 -118.2105       149  1325376044
# 2    38859492057661  220.11  83252  42.1808 -112.2620      4154  1325376051
# 3  3534093764340240   45.00  59632  46.2306 -112.1138      1939  1325376076
# 4   375534208663984   41.96  24433  38.4207  -79.4629        99  1325376186
#
#    merch_lat  merch_long  is_fraud
# 0  36.011293  -82.048315         0
# 1  49.159047 -118.186462         0
# 2  43.150704 -112.154481         0
# 3  47.034331 -112.561071         0
# 4  38.674999  -78.632459         0
#
# Non-Numeric Columns:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# ...

# %%
# Calculate the correlation matrix for numeric columns in numeric_df
correlation_matrix_numeric = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix_numeric)
# Out:
#               cc_num       amt       zip       lat      long  city_pop  \
# cc_num      1.000000  0.001769  0.041459 -0.059271 -0.048278 -0.008991
# amt         0.001769  1.000000  0.001843 -0.001926 -0.000187  0.005818
# zip         0.041459  0.001843  1.000000 -0.114290 -0.909732  0.078467
# lat        -0.059271 -0.001926 -0.114290  1.000000 -0.015533 -0.155730
# long       -0.048278 -0.000187 -0.909732 -0.015533  1.000000 -0.052715
# city_pop   -0.008991  0.005818  0.078467 -0.155730 -0.052715  1.000000
# unix_time   0.000354 -0.000293  0.000670  0.000632 -0.000642 -0.001714
# merch_lat  -0.058942 -0.001873 -0.113561  0.993592 -0.015452 -0.154781
# merch_long -0.048252 -0.000151 -0.908924 -0.015509  0.999120 -0.052687
# is_fraud   -0.000981  0.219404 -0.002162  0.001894  0.001721  0.002136
#
#             unix_time  merch_lat  merch_long  is_fraud
# cc_num       0.000354  -0.058942   -0.048252 -0.000981
# amt         -0.000293  -0.001873   -0.000151  0.219404
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix for numeric columns in numeric_df
correlation_matrix_numeric = numeric_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap using Seaborn
sns.heatmap(correlation_matrix_numeric, annot=True, cmap='coolwarm', fmt='.2f')

# Set title and labels
plt.title('Correlation Matrix of Numeric Columns', fontsize=16)
plt.xlabel('Numeric Columns', fontsize=12)
plt.ylabel('Numeric Columns', fontsize=12)

# Display the heatmap
plt.show()

# %%
# Drop the 'times' column from df_train
df_train.drop(columns=['date', 'time'], inplace=True)

# Display the modified DataFrame
print(df_train.head())
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip      lat  \
# 0                561 Perry Cove  Moravian Falls    NC  28654  36.0788
# ...

# %%
df_test = pd.read_csv('/Users/miftahulardli/Downloads/testFraud/fraudTest.csv')

# %%
df_train
# Out:
#         trans_date_trans_time               cc_num  \
# 0         2019-01-01 00:00:18     2703186189652095
# 1         2019-01-01 00:00:44         630423337322
# 2         2019-01-01 00:00:51       38859492057661
# 3         2019-01-01 00:01:16     3534093764340240
# 4         2019-01-01 00:03:06      375534208663984
# ...                       ...                  ...
# 1296670   2020-06-21 12:12:08       30263540414123
# 1296671   2020-06-21 12:12:19     6011149206456997
# 1296672   2020-06-21 12:12:32     3514865930894695
# 1296673   2020-06-21 12:13:36     2720012583106919
# 1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# 2                       fraud_Lind-Buckridge  entertainment  220.11
# 3         fraud_Kutch, Hermiston and Farrell  gas_transport   45.00
# ...

# %%
df_test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
#delete some weird columns
df_test = df_test.drop('Unnamed: 0', axis='columns')

# %%
#Feature Engineering
df_train.drop(columns=["merchant", "first", "last", "street","unix_time", "trans_num"], inplace=True)
df_test.drop(columns=["merchant", "first", "last", "street","unix_time", "trans_num"], inplace=True)
print(df_train.shape)
print(df_test.shape)
# Out:
# (1296675, 16)
# (555719, 16)

# %%
#training data
x_train=df_train.drop("is_fraud",axis=1)
y_train=df_train["is_fraud"]



#testing data
x_test=df_test.drop("is_fraud",axis=1)
y_test=df_test["is_fraud"]
x_train.info()
print(x_train.shape)
print(x_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  datetime64[ns]
#  1   cc_num                 1296675 non-null  int64
#  2   category               1296675 non-null  object
#  3   amt                    1296675 non-null  float64
#  4   gender                 1296675 non-null  object
#  5   city                   1296675 non-null  object
#  6   state                  1296675 non-null  object
#  7   zip                    1296675 non-null  int64
#  8   lat                    1296675 non-null  float64
#  9   long                   1296675 non-null  float64
#  10  city_pop               1296675 non-null  int64
#  11  job                    1296675 non-null  object
#  12  dob                    1296675 non-null  object
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder

#numerical features
num_feats=x_train.drop(["trans_date_trans_time","category","gender","city","state","job","dob"],axis=1)
num_feats_pipe=Pipeline([
    ("scalar",MinMaxScaler())
    ])
num_feats_preprocessed=num_feats_pipe.fit_transform(num_feats)

#catagorical features
cat_feats=x_train[["trans_date_trans_time","category","gender","city","state","job","dob"]]
cat_feats_pipe=Pipeline([
    ("encoder",OneHotEncoder())
    ])
cat_feats_preprocessed=cat_feats_pipe.fit_transform(cat_feats)
print(num_feats)
# Out:
#                       cc_num     amt    zip      lat      long  city_pop  \
# 0           2703186189652095    4.97  28654  36.0788  -81.1781      3495
# 1               630423337322  107.23  99160  48.8878 -118.2105       149
# 2             38859492057661  220.11  83252  42.1808 -112.2620      4154
# 3           3534093764340240   45.00  59632  46.2306 -112.1138      1939
# 4            375534208663984   41.96  24433  38.4207  -79.4629        99
# ...                      ...     ...    ...      ...       ...       ...
# 1296670       30263540414123   15.56  84735  37.7175 -112.4777       258
# 1296671     6011149206456997   51.70  21790  39.2667  -77.5101       100
# 1296672     3514865930894695  105.93  88325  32.9396 -105.8189       899
# 1296673     2720012583106919   74.90  57756  43.3526 -102.5411      1126
# 1296674  4292902571056973207    4.30  59871  45.8433 -113.8748       218
#
#          merch_lat  merch_long
# 0        36.011293  -82.048315
# ...

# %%
from sklearn.compose import ColumnTransformer
num_list=list(num_feats)
cat_list=list(cat_feats)

final_pipeline=ColumnTransformer([
    ("num",num_feats_pipe,num_list),
    ("cat",cat_feats_pipe,cat_list)])
X_train_preprocessed=final_pipeline.fit_transform(x_train)
X_train_preprocessed

X_test_preprocessed = final_pipeline.fit_transform(x_test)
X_test_preprocessed
# Out:
# <555719x547071 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8331935 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=50, random_state=21)

# %%
# Train the model on the preprocessed training data
print("Training started...")
rf_model.fit(X_train_preprocessed, y_train)
print("Training completed!")
# Out:
# Training started...

# %%
# Predict on the preprocessed test data
#predictions = rf_model.predict(X_test_preprocessed)

# %%
# Evaluate the model, e.g., with accuracy
#accuracy = rf_model.score(X_test_preprocessed, y_test)
#print(f"Accuracy on test data: {accuracy:.4f}")
